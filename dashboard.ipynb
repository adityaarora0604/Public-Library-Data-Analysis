# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import warnings
warnings.filterwarnings("ignore")


sys.path.append('src')


from load_and_clean import load_data, clean_data
from visualizations import run_visuals
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=pd.errors.SettingWithCopyWarning)

# %%
#Cleaning the data:
file_path = "data/libraries.csv"  # or use cleaned_libraries.csv if already processed
df = load_data(file_path)

if df is not None:
    df = clean_data(df)
    df.head()  
else:
    print("Data loading failed.")
# Out:
# Data loaded successfully with 5105 rows and 29 columns.
# Cleaning data...
# Cleaning complete.

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from src.visualizations import run_visuals

df = pd.read_csv("data/cleaned_libraries.csv")
run_visuals(df)
# Out:
# Press Enter to continue...
# Press Enter to continue...
# Press Enter to continue...
# Press Enter to continue...
# Press Enter to continue...
# Press Enter to continue...

# %%
import os
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
df.to_csv("data/cleaned_libraries.csv", index=False)
print("Cleaned data saved.")
# Out:
# Cleaned data saved.

# %% [markdown]
# Insights:
#
# - Libraries with higher populations often report more visits, but not always.
# - Tax appropriation and total circulation show regional variations.
# - Program attendance per capita highlights community engagement levels.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Understanding usage, population, and funding across libraries.

# %%
from src.eda import run_eda
run_eda("data/cleaned_libraries.csv")

# %% [markdown]
# Statistical Testing:

# %%
from src.stat_tests import run_stats
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
df = pd.read_csv("data/cleaned_libraries.csv")
run_stats(df)
# Out:
# Hypothesis Test: Does population affect per capita program attendance?
#
# 🔹 t-statistic: -6.351
# 🔹 p-value: 0.0000
# Statistically significant difference in per capita attendance!
# Conclusion: The hypothesis is supported
